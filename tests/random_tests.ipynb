# %%
import smart_import
# Out:
# Kernel is started

# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import annotations

from scifit.funcs import Sin, SinParams, Lorentzian, LorentzianParams, Polynomial, PolynomialParams
from scifit.models import Fitter

from typing import NamedTuple, Any,Callable
from scipy.optimize import leastsq, curve_fit, least_squares, minimize, basinhopping
import numpy as np

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scifit.funcs import Sin, SinParams
from scifit.models import Fitter
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(20, 30, 20)
y = np.sin(x)
plt.plot(x, y, '.')

# %%
f = Fitter(Sin()).fit(x, y)
y_pred = f.predict(x)
plt.plot(x, y, '.')
plt.plot(x, y_pred)

# %%
x = np.linspace(0, 10, 1000)
y_data = Lorentzian().func(x, 2, 2, 5, 1)+2*(np.random.random(len(x))-.5) #2*np.sin(2*x+np.pi/3)+(np.random.random(len(x))-.5)+2

# %%
(x-150)**2 =

# %%
x = np.linspace(100, 200, 100)


amplitudes = [150**2, -300, 1]
y_data = Polynomial().func(x, *amplitudes) + 300*(np.random.random(len(x))-.5)

# %%
f = Fitter(Polynomial(2))
fm = f.fit(x, y_data)
y_pred = fm.predict(x)
plt.plot(x, y_data, '.')
plt.plot(x, y_pred)

# %%
fm.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/4cd87a/Documents/Projects/PhD/codes/scifit/tests/random_tests.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/4cd87a/Documents/Projects/PhD/codes/scifit/tests/random_tests.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> fm.params
#
# NameError: name 'fm' is not defined
