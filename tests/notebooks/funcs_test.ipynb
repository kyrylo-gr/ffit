# %%
# %load_ext autoreload
# %autoreload 2
# import ffit.backends.jax_fit as jf

import ffit as ff

from scipy.optimize import leastsq, minimize
import jax
import jax.numpy as jnp
from numba import njit
import numpy as np

import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100_000)
y = 2 * x + 3 + np.random.normal(0, 1, len(x))

z = ff.Line.fit(x, y).res_func(x)

fig, ax = plt.subplots()
ax.plot(x, y, "o")
ax.plot(x, z)

# %%
x = np.linspace(0, 10, 100_000)
y = 2 * x + 10 + np.random.normal(0, 1, len(x))
fig, ax = plt.subplots()
ax.plot(x, y, "o")

z = ff.Line.fit(x, y).plot(ax, label="$\\alpha$=$1.2f")
ax.legend()
# ax.set_title("something")

# .params_to_title()

# %%
z.x
# Out:
# Array([0.00000e+00, 1.00001e-04, 2.00002e-04, ..., 9.99980e+00,
#        9.99990e+00, 1.00000e+01], dtype=float32)

# %%
import re

label = r"\$(\d)(\.\d[fed])?"

re.findall(label, "$1.0f $2.0f")
# Out:
# [('1', '.0f'), ('2', '.0f')]

# %%
# Out:
# <Axes: >

# %%
from ffit.fit_logic import FitResult

# %%
ax.get_xlim()
# Out:
# (-0.5, 10.5)

# %%
FitResult([1, 2], lambda x: x, [2, 3]).x
# Out:
# [2, 3]

# %%
# %timeit ff.Line.fit(x, y).res_func(x)
# Out:
# 23.8 ms ± 1.18 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
