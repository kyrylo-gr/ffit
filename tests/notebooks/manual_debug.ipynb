# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import ffit as ff
import aplot as ap

# %%
from ffit.funcs.gaussian import Gaussian as cls

param = [0.2] * len(cls._result_class.keys)  # (1, 1, 1, 1, 1)

# %%
x = np.linspace(-1, 1, 1000)
y = cls.mask().func(x, *param)

fig, ax = plt.subplots()
ax.plot(x, np.real(y))
# guess = cls().guess(x, y).plot(ax, post_func_y=lambda x: np.real(x))
fit = cls().fit(x, y, maxfev=20000).plot(ax, post_func_y=lambda x: np.real(x))

# %%
ff.Gaussian()
# Out:
# $\frac{A}{\sqrt{2\pi}\,\sigma}\exp\left(-\frac{(x - \mu)^2}{2 \sigma^2}\right) + b$

# %%
fit
# Out:
# GaussianResult(('mu', 'sigma', 'amplitude', 'offset'))

# %%
y = np.array(
    [
        1.00000000e00 + 0.00000000e00j,
        9.03279286e-01 + 2.96665526e-01j,
        7.27903034e-01 + 5.35943649e-01j,
        4.98503728e-01 + 7.00050533e-01j,
        2.42607231e-01 + 7.80230016e-01j,
        -1.23252613e-02 + 7.76738813e-01j,
        -2.41564782e-01 + 6.97955600e-01j,
        -4.25259829e-01 + 5.58784893e-01j,
        -5.49900609e-01 + 3.78578888e-01j,
        -6.09025134e-01 + 1.78825914e-01j,
        -6.03171272e-01 - 1.91470177e-02j,
        -5.39151856e-01 - 1.96235227e-01j,
        -4.28788476e-01 - 3.37202985e-01j,
        -2.87279248e-01 - 4.31795230e-01j,
        -1.31394634e-01 - 4.75257536e-01j,
        2.23064754e-02 - 4.68270546e-01j,
        1.59068705e-01 - 4.16361522e-01j,
        2.67203576e-01 - 3.28900537e-01j,
        3.38932906e-01 - 2.17818953e-01j,
        3.70770448e-01 - 9.62016391e-02j,
        3.63448975e-01 + 2.30978621e-02j,
        3.21443591e-01 + 1.28686602e-01j,
        2.52176459e-01 + 2.11601174e-01j,
        1.65010998e-01 + 2.65947019e-01j,
        7.01537043e-02 + 2.89177508e-01j,
        -2.24206096e-02 + 2.82020238e-01j,
        -1.03917755e-01 + 2.48091618e-01j,
        -1.67466985e-01 + 1.93267204e-01j,
        -2.08605176e-01 + 1.24892580e-01j,
        -2.25480057e-01 + 5.09269167e-02j,
        -2.18779725e-01 - 2.08909308e-02j,
        -1.91421575e-01 - 8.37747474e-02j,
        -1.48054064e-01 - 1.32460176e-01j,
        -9.44378014e-02 - 1.63571070e-01j,
        -3.67778122e-02 - 1.75766799e-01j,
        1.89233141e-02 - 1.69677218e-01j,
        6.74304188e-02 - 1.47652021e-01j,
        1.04711765e-01 - 1.13366732e-01j,
        1.28215970e-01 - 7.13374496e-02j,
        1.36978191e-01 - 2.64003825e-02j,
        1.31561646e-01 + 1.67897886e-02j,
        1.13855958e-01 + 5.41956732e-02j,
        8.67657408e-02 + 8.27309668e-02j,
        5.38302706e-02 + 1.00469573e-01j,
        1.88179097e-02 + 1.06721669e-01j,
        -1.46628121e-02 + 1.01982098e-01j,
        -4.34991874e-02 + 8.77683662e-02j,
        -6.53297634e-02 + 6.63746378e-02j,
        -7.87020889e-02 + 4.05737468e-02j,
        -8.31267985e-02 + 1.33012284e-02j,
        -7.90327311e-02 - 1.26461313e-02j,
        -6.76369577e-02 - 3.48692752e-02j,
        -5.07505510e-02 - 5.15622476e-02j,
        -3.05451801e-02 - 6.16310491e-02j,
        -9.30702086e-03 - 6.47317520e-02j,
        1.07968401e-02 - 6.12319229e-02j,
        2.79179626e-02 - 5.21064773e-02j,
        4.06759129e-02 - 3.87844046e-02j,
        4.82477053e-02 - 2.29660082e-02j,
        5.03943757e-02 - 6.43128858e-03j,
        4.74281373e-02 + 9.14102421e-03j,
        4.01290272e-02 + 2.23271911e-02j,
        2.96240111e-02 + 3.20725882e-02j,
        1.72439244e-02 + 3.77589274e-02j,
        4.37430761e-03 + 3.92225349e-02j,
        -7.68475248e-03 + 3.67266095e-02j,
        -1.78369967e-02 + 3.08945845e-02j,
        -2.52771478e-02 + 2.26148162e-02j,
        -2.95413603e-02 + 1.29286367e-02j,
        -3.05195797e-02 + 2.91426651e-03j,
        -2.84322665e-02 - 6.42171058e-03j,
        -2.37771773e-02 - 1.42354715e-02j,
        -1.72542581e-02 - 1.99124753e-02j,
        -9.67806893e-03 - 2.31052700e-02j,
        -1.88746212e-03 - 2.37416612e-02j,
        5.33842697e-03 - 2.20052957e-02j,
        1.13503031e-02 - 1.82932005e-02j,
        1.56794557e-02 - 1.31566255e-02j,
        1.80660447e-02 - 7.23255329e-03j,
        1.84643332e-02 - 1.17344291e-03j,
        1.70265698e-02 + 4.41778445e-03j,
        1.40691434e-02 + 9.04168946e-03j,
        1.00260083e-02 + 1.23410006e-02j,
        5.39513614e-03 + 1.41217412e-02j,
        6.83880918e-04 + 1.43564272e-02j,
        -3.64132157e-03 + 1.31707472e-02j,
        -7.19643701e-03 + 1.08166086e-02j,
        -9.70930736e-03 + 7.63548370e-03j,
        -1.10354010e-02 + 4.01655749e-03j,
        -1.11596233e-02 + 3.54250135e-04j,
        -1.01853503e-02 - 2.99068870e-03j,
        -8.31298175e-03 - 5.72306947e-03j,
        -5.81110680e-03 - 7.63570521e-03j,
        -2.98380190e-03 - 8.62112940e-03j,
        -1.37614556e-04 - 8.67247876e-03j,
        2.44852110e-03 - 7.87449592e-03j,
        4.54778986e-03 - 6.38647725e-03j,
        6.00257201e-03 - 4.41960014e-03j,
        6.73314196e-03 - 2.21137707e-03j,
        6.73794700e-03 - 8.25160523e-18j,
    ]
)

# %%
# param = ff.ComplexSpiralParam(
#     amplitude0=1,
#     frequency=1,
#     phi0=0,
#     tau=1,
#     offset_amp=0,
#     offset_phase=0,
# )


param = [1, 1, 0, 1, 0, 0]

x = np.linspace(0, 5, 100)

ax = ap.axs()
# y = ff.ComplexSpiral.func(x, *param)
ax.plot(x, np.real(y))

fit = ff.ComplexSpiral.ExpDecay().fit(x, y)
fit.plot(
    post_func_y=(lambda x: np.real(x)),
    ax=ax,
    label=(
        fit.label.offset.abs.n("offset").f(),
        fit.label.amplitude.abs.n("amp").u("μs", -6).f(),
        f"amp = {np.abs(fit.amplitude):.2f}μs",
        "\n",
        fit.label.amplitude0.n("amp").u("μs").s,
        fit.label.tau.n("τ").u("μs", 6).s,
    ),
)
print(
    fit.label.amplitude.abs.n("amp").u("μs", -6).f(),
)
# Out:
# amp = 1.00e-6 μs
# <AFigure size 640x480 with 1 Axes>

# %%
len("\n")
# Out:
# 1
